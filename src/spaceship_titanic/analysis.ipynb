# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

display(train.isnull().sum())
display(test.isnull().sum())
dataset = pd.concat([train, test], ignore_index=True)

# Cabin列をスラッシュで分割して新しい列として追加
dataset[['Cabin_deck', 'Cabin_num', 'Cabin_side']] = dataset['Cabin'].str.split('/', expand=True)
dataset.drop(columns=['Cabin'], inplace=True)

display(dataset)
display(dataset.isnull().sum())
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Cabin           199
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# Name            200
# Transported       0
# dtype: int64
# PassengerId       0
# HomePlanet       87
# CryoSleep        93
# Cabin           100
# Destination      92
# Age              91
# VIP              93
# RoomService      82
# FoodCourt       106
# ShoppingMall     98
# Spa             101
# VRDeck           80
# Name             94
# dtype: int64
#       PassengerId HomePlanet CryoSleep    Destination   Age    VIP  \
# 0         0001_01     Europa     False    TRAPPIST-1e  39.0  False
# 1         0002_01      Earth     False    TRAPPIST-1e  24.0  False
# 2         0003_01     Europa     False    TRAPPIST-1e  58.0   True
# 3         0003_02     Europa     False    TRAPPIST-1e  33.0  False
# ...

# %%
sns.pairplot(dataset, hue='Transported')

# %% [markdown]
# # 各変数と Transported の関係

# %%
display(dataset.columns)
# Out:
# Index(['PassengerId', 'HomePlanet', 'CryoSleep', 'Destination', 'Age', 'VIP',
#        'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'Name',
#        'Transported', 'Cabin_deck', 'Cabin_num', 'Cabin_side'],
#       dtype='object')

# %% [markdown]
# ## PassengerId

# %% [markdown]
# ## HomePlanet

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(data=dataset, x='HomePlanet', hue='Transported', ax=ax[0])
sns.barplot(data=dataset, x='HomePlanet', y='Transported', ax=ax[1]).set(ylim=(0, 1), ylabel='Transported Rate')
plt.show()

# %% [markdown]
# ## CryoSleep

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(data=dataset, x='CryoSleep', hue='Transported', ax=ax[0])
sns.barplot(data=dataset, x='CryoSleep', y='Transported', ax=ax[1]).set(ylim=(0, 1), ylabel='Transported Rate')
plt.show()

# %% [markdown]
# ## Destination

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(data=dataset, x='Destination', hue='Transported', ax=ax[0])
sns.barplot(data=dataset, x='Destination', y='Transported', ax=ax[1]).set(ylim=(0, 1), ylabel='Transported Rate')
plt.show()

# %% [markdown]
# ## Age

# %%
sns.histplot(data=dataset, x='Age', hue='Transported', kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## VIP

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(data=dataset, x='VIP', hue='Transported', ax=ax[0])
sns.barplot(data=dataset, x='VIP', y='Transported', ax=ax[1]).set(ylim=(0, 1), ylabel='Transported Rate')
plt.show()

# %% [markdown]
# ## RoomService

# %%
sns.histplot(data=dataset, x='RoomService', hue='Transported', kde=True)
# Out:
# <Axes: xlabel='RoomService', ylabel='Count'>

# %% [markdown]
# ## FoodCourt

# %%
sns.histplot(data=dataset, x='FoodCourt', hue='Transported', kde=True)
# Out:
# <Axes: xlabel='FoodCourt', ylabel='Count'>

# %% [markdown]
# ## ShoppingMall

# %%
sns.histplot(data=dataset, x='ShoppingMall', hue='Transported', kde=True)
# Out:
# <Axes: xlabel='ShoppingMall', ylabel='Count'>

# %% [markdown]
# ## Spa

# %%
sns.histplot(data=dataset, x='Spa', hue='Transported', kde=True)
# Out:
# <Axes: xlabel='Spa', ylabel='Count'>

# %% [markdown]
# ## VRDeck

# %%
sns.histplot(data=dataset, x='VRDeck', hue='Transported', kde=True)
# Out:
# <Axes: xlabel='VRDeck', ylabel='Count'>

# %% [markdown]
# ## Name

# %% [markdown]
# ## Cabin

# %% [markdown]
# ### Cabin_deck

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(data=dataset, x='Cabin_deck', hue='Transported', order=sorted(dataset['Cabin_deck'].dropna()), ax=ax[0])
sns.barplot(data=dataset, x='Cabin_deck', y='Transported', order=sorted(dataset['Cabin_deck'].dropna()), ax=ax[1]).set(ylim=(0, 1), ylabel='Transported Rate')
plt.show()

# %% [markdown]
# ### Cabin_num

# %%
sns.histplot(data=dataset, x='Cabin_num', hue='Transported', kde=True)
# Out:
# <Axes: xlabel='Cabin_num', ylabel='Count'>

# %% [markdown]
# ### Cabin_side

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
sns.countplot(data=dataset, x='Cabin_side', hue='Transported', ax=ax[0])
sns.barplot(data=dataset, x='Cabin_side', y='Transported', ax=ax[1]).set(ylim=(0, 1), ylabel='Transported Rate')
plt.show()
